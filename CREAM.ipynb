# %% [markdown]
# # CREAM Exploration

# %% [markdown]
# Looking at the new and improved CREAM toolkit.

# %%
import pandas as pd
import numpy as np
from sentence_transformers import SentenceTransformer, util
import json
import re
from operator import itemgetter
import swifter

# %%
# load sample keywords, rules, and data
keywords = [
    "bachelor",
    "master",
    "degree",
    "high school",
    "education",
    "diploma",
    "ged",
    "certification"
]
rules = pd.read_csv("data/demo/CREAM/education_rules.csv")
with open("data/demo/TaskMatch/sample_job_ads_in_line.csv", 'r') as f:
    data = [x.strip() for x in f.readlines()]
data = pd.DataFrame(data, columns=["Job Description"])

keywords, rules, data
# Out:
# (['bachelor',
#   'master',
#   'degree',
#   'high school',
#   'education',
#   'diploma',
#   'ged',
#   'certification'],
#                                     rule  education
#  0                              bachelor          0
#  1                                master          0
#  2                                degree          0
#  3                           high school          0
#  4                             education          0
#  ..                                  ...        ...
#  89           at least a bachelor degree          1
#  90  must be a graduate of an accredited          1
#  91                  needed ba bs degree          1
#  92          bachelors degree experience          1
#  93             experience or a bachelor          1
#
#  [94 rows x 2 columns],
#                                           Job Description
#  0         ﻿Wash and fold the clothes and do the laundry.
#  1      Pack luggage for travel and move bags to the p...
#  2                                       Wash the dishes.
#  3                               Help the baby as needed.
#  4                                 Write songs and music.
#  ...                                                  ...
#  27705  This position is in the Central Processing/Rec...
#  27706  The MLT will provide general laboratory receip...
#  27707  The MLT will also provide support to all other...
#  27708  This is a team oriented environment and a succ...
#  27709  This CAP Accredited Laboratory at the Universi...
#
#  [27710 rows x 1 columns])

# %%
# sbert model
#model = SentenceTransformer("sentence-transformers/all-MiniLM-L6-v2")
model = SentenceTransformer("thenlper/gte-large")

# %%
# vectorize rules
encoded_rules = model.encode(rules['rule'].tolist())
rule_map = dict(zip(rules['rule'].tolist(), rules['education'].tolist()))
len(encoded_rules)
# Out:
# 94

# %%
# similarity function
def get_sim(model, rule_map, encoded_rules, q):
    sim_scores = util.cos_sim(model.encode([q]), encoded_rules)
    return dict(zip(rule_map.keys(), sim_scores[0].tolist()))

# %%
scores = get_sim(model, rule_map, encoded_rules, "bachelor degree required")
scores
# Out:
# {'bachelor': 0.887619137763977,
#  'master': 0.8026555776596069,
#  'degree': 0.8911867737770081,
#  'high school': 0.7840946912765503,
#  'education': 0.8150884509086609,
#  'diploma': 0.8584140539169312,
#  'ged': 0.8136746883392334,
#  'certification': 0.8032225370407104,
#  'qualifications associate degree ': 0.8551264405250549,
#  'accredited college or university ': 0.8332047462463379,
#  'at least a bachelor degree': 0.8332047462463379,
#  'ba bs degree in a related': 0.9294393658638,
#  'bachelor degree and years work experience': 0.8935132026672363,
#  'bachelor degree ba bs': 0.921425461769104,
#  'bachelor degree in a': 0.9164381623268127,
#  'bachelor degree or equivalent': 0.9259461760520935,
#  'bachelor degree skills': 0.9242619872093201,
#  'bs ba degree in related field': 0.9198769927024841,
#  'bs degree or equivalent': 0.8903144598007202,
#  'bs or ms degree': 0.903844952583313,
#  'college degree programs': 0.8594380021095276,
#  'degree required bachelor degree': 0.8599889874458313,
#  'education and experience bachelor degree': 0.9810521602630615,
#  'education bachelor degree': 0.9181662201881409,
#  'education from accredited colleges': 0.8993403315544128,
#  'education level bachelor degree': 0.8329702019691467,
#  'experience bachelor degree ': 0.927107036113739,
#  'experience bachelor degree and years': 0.9100528955459595,
#  'foreign colleges or universities': 0.8997148871421814,
#  'from an accredited college or university': 0.8197148442268372,
#  'minimum degree required bachelor degree': 0.8492277264595032,
#  'must be a graduate of an accredited': 0.965083122253418,
#  'needed ba bs degree': 0.8978999853134155,
#  'needed bachelor degree': 0.9385455250740051,
#  'nursing degree': 0.974908173084259,
#  'preferred undergraduate degree': 0.840790867805481,
#  'preferred undergraduate degree or equivalent': 0.8743643164634705,
#  'qualifications bachelor degree': 0.8728945255279541,
#  'technical degree bachelors masters': 0.9112548232078552,
#  'technical degree bachelors masters or phd': 0.8837389945983887,
#  'associate degree and or diploma': 0.877355694770813,
#  'experience high school diploma': 0.8610573410987854,
#  'qualifications high school': 0.7993294596672058,
#  'national certification or high school': 0.8358246684074402,
#  'minimum level of education high school': 0.8226690292358398,
#  'high school education': 0.8308162093162537,
#  'high school degree ged ': 0.8089480996131897,
#  'high school degree': 0.8358925580978394,
#  'ged equivalent': 0.8585959076881409,
#  'full time degree preferred high school': 0.8115208148956299,
#  'experience knowledge high school': 0.8234824538230896,
#  'education high school diploma': 0.7845533490180969,
#  'education high school ': 0.7993294596672058,
#  'education high schhol experience': 0.7993294596672058,
#  'education experience high school': 0.835809588432312,
#  'education and experience high school': 0.8055074214935303,
#  'diploma or general education development ged': 0.8129186630249023,
#  'diploma or general education degree ged': 0.777151346206665,
#  'diploma or general education degree': 0.7898616790771484,
#  'diploma or ged': 0.8185664415359497,
#  'diploma or equivalent': 0.8290064930915833,
#  'diploma ged': 0.8500159978866577,
#  'degree required high school': 0.8434367775917053,
#  'a high school degree': 0.8551820516586304,
#  'diploma ged with years of experience': 0.8335086703300476,
#  'general education degree ged': 0.9072276949882507,
#  'high school qualification': 0.8702530860900879,
#  'preferred high school degree ged': 0.8462002277374268,
#  'certification or pharmacy license': 0.799329400062561,
#  'doctoral degree in nursing': 0.799329400062561,
#  'has doctoral degree': 0.8222983479499817,
#  'pharmacy license': 0.8585959076881409,
#  'master degree in nursing': 0.8370574116706848,
#  'bachelors degree experience': 0.8225646018981934,
#  'experience or a bachelor': 0.8063866496086121}

# %%
# label via max score
def label_from_max(scores, rule_map):
    max_rule = max(scores, key=scores.get)
    label = rule_map[max_rule]
    return max_rule, label, scores[max_rule]

# %%
label_from_max(scores, rule_map)
# Out:
# ('education and experience bachelor degree', 1, 0.9810521602630615)

# %%
# if keyword found, get context window for similarity scoring
def get_context(text, keywords):
    n = 4
    text = text.lower()
    text = re.sub(r'[^a-z0-9]+', ' ', text)

    words = text.split()
    found_index = [i for i, w in enumerate(words) if any(k.strip() in w for k in keywords)]
    context = [" ".join(words[max(0, idx-n):min(idx+n+1, len(words))]) for idx in found_index]

    return '|'.join(context)

# %%
results = data["Job Description"].apply(lambda x: get_context(x, keywords))
[x for x in results if x != ""]
# Out:
# ['a team of higher education professionals',
#  'and risk taking are encouraged and every employee has',
#  'bachelor s degree preferred or|bachelor s degree preferred or equivalent combination|or equivalent combination of education training and experience',
#  'hand tools high school diploma or ged|high school diploma or ged',
#  'other state and local certifications',
#  'relationships through project interaction bachelor s degree in civil|project interaction bachelor s degree in civil or environmental',
#  'master s in environmental engineering',
#  'bachelor s degree in construction|bachelor s degree in construction management engineering',
#  'hospitality primary and higher education justice and solar energy',
#  'oversee the certification and final funding of',
#  'of a high school degree required',
#  'bachelor s degree preferred in|bachelor s degree preferred in business finance',
#  'data query programs are managed appropriately',
#  'high school diploma required',
#  'relationships comprehensive training ongoing education and networking opportunities with',
#  'healthcare or higher education experienc',
#  'or type ii hvac certification previous industry experience rotating',
#  'associates degree or equivalent experience',
#  'aa as degree in chemical mechanical computer|or equivalent combination of education and job experience',
#  'building space which is managed by a team of',
#  'industry vendor specific certifications training ncti scte ccna|or other industry accredited certification',
#  'high school diploma or equivalent work experience',
#  'experience with consumer education of products services',
#  'high school diploma or equivalent work experience',
#  'industry and vendor specific certifications and training ncri scte',
#  'support cpn home certification and end of line',
#  'bachelor s degree in electronic|bachelor s degree in electronic engineering or',
#  'industry and vendor specific certifications and training',
#  'wide tiered support on converged distribution and access network',
#  'duties requested by manager bachelor s degree in computer|by manager bachelor s degree in computer science engineering',
#  'valid certifications from the society of',
#  'plan have a hs diploma or ged be at|a hs diploma or ged be at least 18',
#  'vocational technical school education with an emphasis on',
#  'industrial training certification in instrumentation with a',
#  'high school diploma or ged required|high school diploma or ged required',
#  'high school graduate or ged equivalent required',
#  'projects simultaneously within a managed budget and execution schedule',
#  'required bachelor s degree in civil|required bachelor s degree in civil mechanical or',
#  'high school diploma or general equivalency diploma|diploma or general equivalency diploma',
#  'optimize the performance of managed resources relative to the',
#  'bachelors degree in a related|bachelors degree in a related discipline|in lieu of a degree',
#  'green belt certification one which required successful|green or black belt certification',
#  're claimers certification',
#  '2 year technical certification preferred',
#  'high school diploma or equivalent',
#  'license preferred various licenses certifications depending on particular job',
#  'cfc certification backflow certification specific equipment|cfc certification backflow certification specific equipment systems training',
#  'license certifications master electrician|license certifications master electrician',
#  'master electrician preferred',
#  'excellence the joint commission certification as a primary stroke',
#  'bachelor s degree from an|bachelor s degree from an accredited college',
#  'national certification as a mls ascp',
#  'high school diploma or ged|high school diploma or ged',
#  'senior technician requires certification in refrigeration',
#  'able to pass refrigeration certification type i type ii',
#  'high school diploma or ged|high school diploma or ged',
#  'house with a high degree of supervision',
#  'high school diploma or ged|high school diploma or ged',
#  'able to pass refrigeration certification type i type ii',
#  'the pie develops mastery of the processes they|to and uses that mastery to deliver improved te',
#  'travel less than 5 bachelor s degree or equivalent|than 5 bachelor s degree or equivalent experience required',
#  'bachelor s degree preferably in|bachelor s degree preferably in engineering business',
#  'quality improvement management continuing education and patient care programs',
#  'board eligibility or board certification',
#  'of america s largest managed healthcare organizations',
#  'high school diploma or ged|high school diploma or ged',
#  'qualify and maintain dot certification a 2 year technical',
#  'high school or equivalent diploma',
#  'high school diploma or equivalent',
#  'management associates or higher degree from a vocational school',
#  'bachelor s degree or foreign|bachelor s degree or foreign equivalent in',
#  'designing mph strategies advanced degree s degree math engineering|strategies advanced degree s degree math engineering science business',
#  'hands on and engaged style',
#  'bachelor s degree in bioengineering|bachelor s degree in bioengineering chemistry biochemistry',
#  'master s or phd degree|master s or phd degree in biological or chemical',
#  'high school diploma or equivalent',
#  'but not limited to prolonged periods of standing and',
#  'high school education or equivalent is preferred',
#  'individual productivity high school diploma or equivalent is preferred',
#  'experiments and laboratory safety educational background bachelor or master|laboratory safety educational background bachelor or master of science|educational background bachelor or master of science or phd',
#  'and testing high school diploma or ged|high school diploma or ged',
#  'two or four year degree in instrumentation electrical or',
#  'two 2 year technical degree with five 5 years',
#  'high school diploma or equivalent with trade|equivalent with trade school certifications or college level courses',
#  'high school diploma or equivalent preferred',
#  'leadership support during inspections bachelor of science b s|of science b s degree in engineering or science',
#  'bs degree in the biological sciences|related field or ms degree in biological sciences with',
#  'knowledge by participating in educational opportunities',
#  'cnc certificate 2 year degree in manufacturing technology industrial',
#  'high school diploma or equivalent required cnc|equivalent required cnc technology diploma preferred',
#  'technical knowledge by attending educational workshops cross training reviewing',
#  'priority technical associate s degree and 5 years of',
#  'four year accredited undergraduate degree me ae ee in',
#  'knowledge by attending scheduled educational workshops reviewing technical publications',
#  'own function high school education or ged|high school education or ged',
#  'be attained associate s degree in engineering we re',
#  'high school diploma ged|high school diploma ged',
#  'based on business needs bachelor s degree in related|business needs bachelor s degree in related industry',
#  'business development activities a master s or doctoral degree|master s or doctoral degree in health services research',
#  'associate s degree in industrial or maintenance',
#  'bachelor s degree in industrial|bachelor s degree in industrial or mechanical',
#  'or a high school diploma ged and at least|a high school diploma ged and at least 5',
#  'bachelor s degree in industrial|bachelor s degree in industrial engineering bsie',
#  'finance math or accounting degree with a minimum 3',
#  'education high school studies',
#  'license certification designation associates are expected',
#  'high school diploma or equivalent',
#  'safety training licenses and certifications for the job assignment',
#  'support manufacturing training certification and general support where',
#  'high school diploma or ged|high school diploma or ged',
#  'certificate or degree in electronics preferred',
#  'bs degree in mechanical engineering or',
#  'universal remote control certification',
#  'control4 certification',
#  'amx certification',
#  'lutron certification',
#  'savant certification',
#  'cedia icia nicet ecc certification our magnolia care technical',
#  'valid applicable certifications',
#  's discovered high school diploma or equivalent is required',
#  'a high school diploma or equivalent',
#  'master s degree preferred|master s degree preferred',
#  'schedules for graduate medical education gme personnel working in',
#  'bachelor s degree in a|bachelor s degree in a scientific discipline|in laboratory sciences or bachelor s degree in science|sciences or bachelor s degree in science related field',
#  'basic life support bls certification',
#  'master s degree in basic|master s degree in basic laboratory science',
#  'associate s degree trade school certification in|s degree trade school certification in technical field or',
#  'bachelor s degree in mechanical|bachelor s degree in mechanical industrial or',
#  'master s degree in mechanical|master s degree in mechanical electrical or',
#  'and sewage field lines damaged while performing other duties',
#  'work processes standards and master plan are in conformance',
#  'typically a high school diploma ged or equivalent related|a high school diploma ged or equivalent related network',
#  'technical degree preferred',
#  'high school diploma or equivalent required degree|diploma or equivalent required degree from a vocational school',
#  '4 year degree in engineering from abet',
#  'adobe acrobat 4 year degree in architectural engineering preferred',
#  'college degree or equivalent experience',
#  'or an associate s degree in a technical discipline',
#  'used in lieu of education',
#  'flexible hours high school diploma or ged|high school diploma or ged',
#  'members minimum of a bachelor s degree in stem|of a bachelor s degree in stem science technology',
#  'or master s degree in science|or master s degree in science technology engineering',
#  'lean or six sigma certification',
#  'position with an increasing degree of proficiency and decreasing|of proficiency and decreasing degree of supervision with regard',
#  'upon achieving required training certifications and safety requirements',
#  'and provides customer with education on products and services',
#  'upon achieving required training certifications and safety requirements',
#  'high school diploma ged|high school diploma ged',
#  'a combination of prior education level classes and current',
#  'of arts or science degree in stem mechanical engineering',
#  'technical areas beyond current education and area of expertise',
#  'candidate must have a bachelor of science or master|bachelor of science or master of science degree in|or master of science degree in mechanical engineering or|or other equivalent engineering degrees',
#  'bachelor s degree in industrial|bachelor s degree in industrial engineering or',
#  'mtm certification a plus',
#  'production departments high school diploma or ged|high school diploma or ged',
#  'masters of teamwork we challenge',
#  'high school diploma or ged|high school diploma or ged',
#  'school technical vocational school degree or education or related|vocational school degree or education or related military training',
#  'masters of teamwork we challenge',
#  'high school diploma or ged|high school diploma or ged',
#  'employer will accept a master s degree in computer|accept a master s degree in computer science information|related occupation or a bachelor s degree in computer|or a bachelor s degree in computer science information',
#  'have a high school diploma ged or equivalent|a high school diploma ged or equivalent',
#  'have completed high school diploma ged or equivalent|completed high school diploma ged or equivalent',
#  'related associate degree or 2 or more',
#  'a related associate degree or 2 or more',
#  'associate s degree or four or more',
#  'bachelor s degree in engineering|bachelor s degree in engineering or technical',
#  'a high school diploma and a minimum o',
#  'high school diploma',
#  'bachelor s degree in engineering|bachelor s degree in engineering from an',
#  'domestic and international advanced degree',
#  'development internal training medical education review of commercial and',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent in life',
#  'masters phd pharmd in life',
#  'board certification in family medicine internal',
#  '10 30pm high school diploma or general education degree|school diploma or general education degree ged and a|diploma or general education degree ged and a minimum|or general education degree ged and a minimum of',
#  'high school diploma or equivalent is required',
#  'md or do degree required',
#  'board certification in family medicine',
#  'applicable certifications such as comptia a|security or other similar certifications',
#  'bachelor s degree or higher|bachelor s degree or higher in accredited',
#  'bachelor s and 2 or|years experience or a master s degree with experience|or a master s degree with experience',
#  'bachelor master or doctorate of|bachelor master or doctorate of science|or doctorate of science degree from an accredited course',
#  'bachelor of science degree in|bachelor of science degree in one of the',
#  'minimum of a bachelor s degree in engineering|of a bachelor s degree in engineering computer science',
#  'education experience typically acquired through|acquired through advanced technical education from an accredited course',
#  'bachelor and typically 5 or|equivalent combination of technical education and experience e g',
#  'phd master 3 years related work',
#  'million square feet of managed space',
#  'high school diploma or ged and one|high school diploma or ged and one of the',
#  'associate equivalent or higher degree in any field with',
#  'currently pursuing an associates degree in process technology with',
#  'in lieu of a degree dow will consider those',
#  'process technology certification',
#  'discipline deliverables for site managed projects',
#  'support site managed project teams in the',
#  'a minimum of a bachelor s degree in engineering|of a bachelor s degree in engineering is required',
#  'high school diploma or its equivalent',
#  'obtain natural propane gas certifications within 180 days of',
#  'supply own hand tools degree in electrical motor control',
#  'bachelor of science in civil',
#  'verifiable high school diploma or ged is required|high school diploma or ged is required',
#  'technical certifications',
#  'technical degree',
#  'further education or technical degree a|further education or technical degree a plus and must',
#  'high school diploma or ged equivalent|high school diploma or ged equivalent',
#  'to obtain forklift driver certification',
#  'creativity and a high degree of self motivation',
#  'finance or economics degree preferred',
#  'high school diploma ged or high school|high school diploma ged or high school equivalence',
#  'md or phd md degree in life sciences oncology',
#  'with temperature below 10 degrees',
#  'personal ownership high school diploma or ged|high school diploma or ged',
#  'if needed associates or bachelor s degree jpmorgan chase|associates or bachelor s degree jpmorgan chase co',
#  'bachelors degree business finance etc|bachelors degree business finance etc the',
#  'postgraduatetraining certification fellowship in a clinical',
#  'professional demeanor high school diploma ged or equivalent certification|demeanor high school diploma ged or equivalent certification bachelor|diploma ged or equivalent certification bachelor s degree or|ged or equivalent certification bachelor s degree or military|equivalent certification bachelor s degree or military experience',
#  'an advanced degree phd in life science',
#  'degree',
#  'board certification in primary care or',
#  'a high degree of initiative and the',
#  'relevant professional qualifications and certifications e g state registration|clinical scientist or board certification member or fellow in',
#  'requires tact and diplomacy when exchanging complex or',
#  'bachelors degree experience in mortgage|bachelors degree experience in mortgage loan',
#  'bachelor s degree in mis|bachelor s degree in mis computer science',
#  'bachelor s degree in cs|bachelor s degree in cs or relevant',
#  's unique contributions are encouraged',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent experience',
#  'degree in computer science or',
#  'seeking an experienced and engaged php developer who is',
#  'to an unmotivated or unengaged programmer with tons of',
#  'we are dynamic engaged highly motivated and highly',
#  'to an unmotivated or unengaged programmer with tons of',
#  'we are dynamic engaged highly motivated and highly',
#  'bs degree in computer science electrical',
#  'ms or phd degree in computer science electrical',
#  'bs degree in computer science or',
#  'platform developer ii certification',
#  'be deeply engaged in the full development',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'be deeply engaged in the full development',
#  'education requirements',
#  'certifications for linux network and',
#  's through our continuing education opportunities our robust training',
#  'education requirements',
#  'a bs degree in computer science math',
#  'higher level degrees ms phd in computer',
#  's through our continuing education opportunities our robust training',
#  'education requirements',
#  'certifications for linux network and',
#  's through our continuing education opportunities our robust training',
#  'education requirements',
#  'bs degree in related field and',
#  'security certification people first',
#  's through our continuing education opportunities our robust training',
#  'work with a high degree of accuracy in a',
#  'bachelor s degree in creative|bachelor s degree in creative field marketing',
#  'bachelor s degree from an|bachelor s degree from an accredited college',
#  'aws certifications a plus',
#  'itil certification a plus',
#  'any programming certification a plus',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'goals priorities escalations volumes aged projects and other associated',
#  'bachelor s degree from an|bachelor s degree from an accredited college',
#  'itil certification a plus',
#  'aws certification a plus',
#  'bachelor s degree or higher|bachelor s degree or higher in an',
#  'in lieu of a bachelor s degree a minimum|of a bachelor s degree a minimum of four',
#  'associate degree or higher in an',
#  'instead of a degree a minimum of eight',
#  'field or equivalent experience education or training',
#  'engaged with business owners business',
#  'standards are established effectively managed and performed',
#  'bachelor s degree in computer|bachelor s degree in computer science engineering',
#  'master s degree a plus|master s degree a plus',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'bachelor s degree or four|bachelor s degree or four or more',
#  'a degree in computer science mathematics|networking focus other related degree or extensive networking experience',
#  'bachelor s degree or four|bachelor s degree or four or more',
#  'a degree in computer science or',
#  'certifications in red hat hp',
#  'bachelor s degree or four|bachelor s degree or four or more',
#  'bachelor s degree or four|bachelor s degree or four or more',
#  'security certifications cissp ccsp cloud certifications|certifications cissp ccsp cloud certifications or willingness to obtain',
#  'fedramp and iso 27001 certification efforts',
#  'bachelors degree or four or|bachelors degree or four or more',
#  'while achieving a high degree of automation security and',
#  'education and experience',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'properly staffed expectations are managed and cost and timelines',
#  'education and experience',
#  'bachelor s degree in computer|bachelor s degree in computer engineering computer',
#  'education and experience',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'education and experience',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'other duties as required education and or experience knowledge',
#  'bachelor s degree in computer|bachelor s degree in computer science engineering',
#  'considered in lieu of degree',
#  'analyst level requires a bachelor s degree or equivalent|requires a bachelor s degree or equivalent experience and',
#  'analyst level requires a bachelor s degree or equivalent|requires a bachelor s degree or equivalent experience and',
#  'analyst level requires a bachelor s degree or equivalent|requires a bachelor s degree or equivalent experience and',
#  'equivalent combination of graduate degree and work experience',
#  'of studies toward a bachelor s technical degree or|a bachelor s technical degree or equivalent experience with',
#  'and verbal communications skills bachelor s degree in computer|communications skills bachelor s degree in computer science network',
#  'continuously improving consumer experiences bachelor s degree in a|consumer experiences bachelor s degree in a technical field',
#  'a bachelor s degree ideally in|a bachelor s degree ideally in a technology',
#  'a record of continuing education and professional development through',
#  'advanced degree master s or ph|advanced degree master s or ph d',
#  'standards training and hiring bachelor s degree in computer|and hiring bachelor s degree in computer science or',
#  'bachelor s degree in computer|bachelor s degree in computer science or|of relevant equivalent experience education and trainin',
#  'ba bs degree or similar college level|or similar college level education in accounting or related',
#  'ba bs degree or similar college level|or similar college level education',
#  'education work experience required',
#  'in lieu of degree 5 years of ap',
#  'bachelor s degree with 0|bachelor s degree with 0 3 years',
#  'bachelor s degree in accounting|bachelor s degree in accounting or finance',
#  'and an associate s degree is preferred',
#  'to enroll in continuing education courses that will result|in your achieving insurance certifications and designations',
#  'focusing on education process improvement open communication',
#  'education or qualifications relating to',
#  '1 years additional education beyond high school',
#  'bachelor or higher degree in|bachelor or higher degree in finance accounting',
#  'insurance personal finance travel education and more',
#  'and resolve system issues bachelor s degree in business|system issues bachelor s degree in business computer science',
#  'or equivalent combination of education and experience',
#  'rec system and other managed packaged applications|system and other managed packaged applications',
#  'bachelor s degree or foreign|bachelor s degree or foreign equivalent in',
#  'rate categories billing class master data customer service and',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent experience',
#  'and with a high degree of personal accountability and',
#  'a quantitative degree in a field like|economics or mathematics advanced degrees preferred',
#  'looker specifically you have managed the data backbone of',
#  'with documentation on going education and other impactful opportunities',
#  'being an advocate for education always growing in your|analytics you have a bachelor s degree in analytics|have a bachelor s degree in analytics statistics marketing',
#  'and reporting dashboards and education to improve clients digital',
#  'insurance personal finance travel education and more',
#  'a bachelor s degree in computer|a bachelor s degree in computer science information',
#  'mining experts and scrum masters that will help achieve',
#  'mining experts and scrum masters that will help achieve',
#  'bachelor s degree in computer|bachelor s degree in computer science information|the equivalent combination of education technical certifications or training|combination of education technical certifications or training or work',
#  '8570 iat ii level certification cna security gicsp gsec',
#  'professional certification in one or more',
#  'success on a new aged digital battlefield is not',
#  'a bachelor s degree from an|a bachelor s degree from an accredited institution',
#  'administration and have a degree in a computer related',
#  'knowledge by participating in educational opportunities',
#  'employee complaints in a diplomatic manner',
#  'expertise to project teams bachelor s degree or education|project teams bachelor s degree or education commensurate via|bachelor s degree or education commensurate via certifications or|or education commensurate via certifications or experience',
#  'other major crm platform certifications',
#  'a fast paced intellectually charged environment and have similar',
#  'auditing lineage metadata and master data management',
#  'ba bs degree from abet accredited college|university two year as degree or hs diploma with|as degree or hs diploma with demonstrated experience',
#  's through our continuing education opportunities our robust training',
#  'bachelor s degree in cs|bachelor s degree in cs or relevant',
#  'required bachelor s degree computer science|required bachelor s degree computer science business administration|cabp or pmi pba certification the business analyst is',
#  'to learning through continuous educational development',
#  'bachelors masters degree or equivalent|bachelors masters degree or equivalent experience|bachelors masters degree or equivalent experience required',
#  'bachelors degree in mathematics statistics|bachelors degree in mathematics statistics data',
#  'other duties as assigned bachelor s degree in a|as assigned bachelor s degree in a quantitative field',
#  'bachelor s degree in engineering|bachelor s degree in engineering computer science',
#  'analytical executives and partners master s degree in engineering|and partners master s degree in engineering computer science',
#  'drive to learn and master new technologies',
#  'bachelor s degree is required|bachelor s degree is required for this',
#  'a bachelor s degree in computer|a bachelor s degree in computer science or',
#  'results goal oriented a master s degree is preferred|oriented a master s degree is preferred headquartered in',
#  'a bachelor s degree in human|a bachelor s degree in human resources business',
#  'an hr certification such as phr sphr',
#  'bachelor of science or bachelor|bachelor of science or bachelor of arts degree required|or bachelor of arts degree required experience in an|team lead or scrum master',
#  'bachelor s degree required experience|bachelor s degree required experience with atlassian',
#  'bachelor s degree or equivalency|bachelor s degree or equivalency cs ce',
#  'bachelor s degree required|bachelor s degree required',
#  'or equivalent education professional experience combination',
#  'customers include health systems educational institutions manufacturers and government',
#  'a visible involved and engaged leader to employees throughout',
#  'ensure a high performing engaged workforce',
#  'associates or bachelor s degree in an|associates or bachelor s degree in an it related',
#  'customized applications and tools bachelor s degree from an|and tools bachelor s degree from an accredited college',
#  'aws certifications a plus',
#  'itil certification a plus',
#  'any programming certification a plus',
#  'education certification bachelor s degree|education certification bachelor s degree preferred|education certification bachelor s degree preferred|education certification bachelor s degree preferred',
#  'aws solutions architect associate certification or comparable experience in',
#  'information systems or cs degree or comparable experience you',
#  'statistical techniques ba bs degree preferably in economics statistics',
#  'leaders to drive efficiencies master s degree in applied|drive efficiencies master s degree in applied economics statistics',
#  'a tight knit group charged with providing actionable insights',
#  'you have a bachelor s or graduate degree|bachelor s or graduate degree business analytics or mathematics',
#  'bachelor s degree in a|bachelor s degree in a quantitative field',
#  'basis azure or aws certifications are preferred the senior',
#  'applied problems within the education space',
#  'bachelor s degree in a|bachelor s degree in a quantitative field',
#  'master s degree in a|master s degree in a quantitative field',
#  'that enable self service bachelor s degree in computer|self service bachelor s degree in computer science math',
#  'or similar college level education knowledge of automation tools',
#  'master s degree in statistics|master s degree in statistics biostatistics mathematics',
#  'and changes reporting and education with manager awareness',
#  'bachelor s degree required|bachelor s degree required',
#  'bachelor s degree in computer|bachelor s degree in computer science information|or relevant combination of education and experience required',
#  'advanced degree phd required in one',
#  'belonging for all employees bachelor s degree in hr|all employees bachelor s degree in hr and a',
#  'prolonged periods sitting at a',
#  'post graduate degree and or sphr certification|degree and or sphr certification preferred betterup is a',
#  'master s degree in relevant|master s degree in relevant technical discipline',
#  'mastery in one or more',
#  'bachelor s degree in employee|bachelor s degree in employee relations human',
#  'its equivalent through training education and other experience',
#  'for automated model reporting master s phd degree in|reporting master s phd degree in statistics math data',
#  'high degree of proficiency with one',
#  'bachelor s degree in a|bachelor s degree in a quantitative field',
#  'you ve managed complex people and process',
#  'ms certifications mcitp or mcsa are',
#  'azure certifications',
#  'bachelor s degree in mis|bachelor s degree in mis statistics computer',
#  'microsoft certifications in azure specifically related',
#  'must have a bachelor s degree in computer|have a bachelor s degree in computer science technology',
#  'must have a bachelor s degree in computer|have a bachelor s degree in computer science technology',
#  'other duties as assigned bachelor s degree ideally in|as assigned bachelor s degree ideally in a technical',
#  'advanced degree ideally in a technical',
#  'years and an advanced degree',
#  'genuinely interested in and engaged with the broader data',
#  'a bachelor s degree|a bachelor s degree',
#  'great place to work certification and tampa bay top',
#  'database standards compliance through education and governance team',
#  'technical knowledge by attending educational workshops',
#  'community meetings conferences and certifications',
#  'bachelor of arts science degree|bachelor of arts science degree in the field of|experience in lieu of degree is required',
#  'bachelor s degree in computational|bachelor s degree in computational biology applied',
#  'of presentations and publications master s degree in computational|and publications master s degree in computational biology applied',
#  'master s degree in related|master s degree in related field or',
#  'train and education business users on technology',
#  'ba bs degree in finance financial engineering',
#  'h s diploma with 2 years of',
#  'bachelors degree preferred|bachelors degree preferred',
#  'proven master of solution architecture with',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'diploma ged with one year|diploma ged with one year of',
#  'bachelors degree or 1 year|bachelors degree or 1 year of|for every year a degree not obtained sas sql',
#  'bachelor s degree plus 4|bachelor s degree plus 4 years of|years of experience or master s degree plus 3|experience or master s degree plus 3 years of',
#  'bachelor s degree required phr|bachelor s degree required phr sphr or|sphr or shrm cp certifications',
#  'masters degree human resources or|masters degree human resources or equivalent',
#  'bachelor s degree|bachelor s degree',
#  'of aws experience aws certifications solutions architect associate developer',
#  'bachelor s degree or military|bachelor s degree or military experience',
#  'management experience mba or master s degree|mba or master s degree',
#  'day you will be challenged on three types of',
#  'build well managed data solutions tools and',
#  'report on data quality degree specialized in a science',
#  'bachelor s degree plus 1|bachelor s degree plus 1 year of|analytics experience or a masters degree|experience or a masters degree',
#  'data languages and platforms master s degree in a|and platforms master s degree in a science technology',
#  'bachelor s degree|bachelor s degree',
#  'of experience in analysis master s degree in business|in analysis master s degree in business or quantitative',
#  'bachelor s degree|bachelor s degree',
#  'bachelor s degree in computer|bachelor s degree in computer science a',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent practical experience',
#  'master s or mba degree|master s or mba degree',
#  'master s degree in a|master s degree in a quantitative discipline',
#  'doctorate s degree in a quantitative discipline',
#  'those into usable products bachelor s degree in a|usable products bachelor s degree in a quantitative discipline',
#  'mba or other advanced degree in a relevant field',
#  'and assistance to managers bachelor s degree in human|to managers bachelor s degree in human resources business',
#  'experience a high school degree or ged and additional|high school degree or ged and additional four 4|considered equivalent to a bachelor s degree|to a bachelor s degree',
#  'in human resources sphr certification preferred communication in multiple',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent in computer',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent in computer',
#  'etl databases meta and master data management and business',
#  'bachelor s degree or four|bachelor s degree or four or more',
#  'bachelor s degree or four|bachelor s degree or four or more',
#  'ma ms degree with a concentration in',
#  'bachelor s degree in accounting|bachelor s degree in accounting finance business',
#  'of business developed through education or past experience',
#  'bachelor s degree from an|bachelor s degree from an accredited university|or a high school diploma ged with at least|a high school diploma ged with at least 4',
#  'master s degree in a|master s degree in a stem major',
#  'review of business expenses bachelor s degree in relevant|business expenses bachelor s degree in relevant field or',
#  'delivering workshops and tutorials master s phd degree or|tutorials master s phd degree or bachelor s degree|s phd degree or bachelor s degree with 2|degree or bachelor s degree with 2 years of',
#  'tenable security center etc masters or ph d',
#  'computer science or equivalent degree is preferred',
#  'degree in computer science or',
#  'self motivated and self managed with a demonstrated analytical',
#  'the completion of a bachelor s degree program or|of a bachelor s degree program or equivalent degree|degree program or equivalent degree in a field of',
#  'to ensure solutions are leveraged for future projects',
#  'the completion of a bachelor s degree program or|of a bachelor s degree program or equivalent degree|degree program or equivalent degree in a field of',
#  'to grow and be challenged using both formal and|and informal development channels masters in a quantitative field',
#  'of a high school diplomas and or ged|school diplomas and or ged',
#  'performance management bachelors degree in human resources|performance management bachelors degree in human resources or',
#  'bachelor s degree and 1|bachelor s degree and 1 2 years',
#  'specialized training or certification in visualization created 2',
#  'skills college or university degree required',
#  'high degree of customer focus and',
#  '4 year degree preferably in information analytics',
#  'year college or university degree is required human resources',
#  'education',
#  'bachelor s degree or higher|bachelor s degree or higher with relevant',
#  'master s or phd preferred',
#  'bs ms degree in computer science engineering',
#  'knowledge and or mastery in many of the',
#  'system abap java administration certification maintenance transport management and',
#  'preferred sap hana certification',
#  'bachelor s degree required technical|bachelor s degree required technical discipline preferred',
#  'bachelor s degree in human|bachelor s degree in human resources related',
#  'bachelor s degree or high|bachelor s degree or high school diploma|degree or high school diploma ged and at least|or high school diploma ged and at least 3',
#  'bachelor s degree and at|bachelor s degree and at least 2|or a high school diploma ged and at least|a high school diploma ged and at least 5',
#  'bachelor s degree in computer|bachelor s degree in computer science',
#  'bachelor s degree and at|bachelor s degree and at least 4',
#  'or graduate degree in a quantitative computational',
#  'graduate degree in a quantitative computational',
#  'team members are actively engaged in the process as',
#  'bachelor s degree and at|bachelor s degree and at least eight|etc or high school diploma ged and at least|or high school diploma ged and at least eleven',
#  'master s degree mba and|master s degree mba and or jd',
#  'the team is motivated engaged and have the right',
#  'degree in business human resources',
#  'master s degree beneficial|master s degree beneficial',
#  'skills with a high degree of initiative and flexibility',
#  'bachelor s degree or an|bachelor s degree or an equivalent combination|an equivalent combination of education and relevant experience exposure',
#  '4 year college degree or equivalent experience',
#  'education level bachelor s degree|education level bachelor s degree preferred|education level bachelor s degree preferred',
#  'and strong organizational health bachelor s degree required|organizational health bachelor s degree required',
#  'strong executive presence required master s degree in business|presence required master s degree in business administration or',
#  'bachelor s degree u s|bachelor s degree u s',
#  'bachelor s degree in information|bachelor s degree in information technology computer',
#  'internal and external audits bachelors degree in it or|and external audits bachelors degree in it or similar',
#  'bachelor s degree or higher|bachelor s degree or higher in chemistry',
#  'to non technical audience bachelors in computer science computer',
#  'vision and matching 401k masters is preferred the insights',
#  'deep understanding of how master data elements interact and',
#  'education bachelor s degree in|education bachelor s degree in computer|education bachelor s degree in computer science information',
#  'bachelor s degree in engineering|bachelor s degree in engineering technology discipline',
#  'experience with technical education and support for b2b',
#  'bachelor s degree in relevant|bachelor s degree in relevant area of',
#  'master s degree preferre|master s degree preferre',
#  'bachelor s degree in information|bachelor s degree in information technology discipline',
#  'level amazon web services certifications',
#  'currently pursuing an advanced degree in analytics',
#  'first level university degree',
#  'advanced university degree preferred',
#  'technical university or bachelor preferred or equivalent experience',
#  'ba bs degree or equivalent plus 5',
#  'or other project management certification a plus imagine what',
#  'bachelor s degree or higher|bachelor s degree or higher in computer',
#  'advanced degree preferred are you a',
#  'bachelor s degree or higher|bachelor s degree or higher in information',
#  'self directed and self managed',
#  'efficiencies on internal processes bachelor s degree or higher|internal processes bachelor s degree or higher in economics',
#  'master s degree or higher|master s degree or higher in economics',
#  'bachelor s degree in any|bachelor s degree in any discipline',
#  'workday certification',
#  'data corrections rescinds maintaining master data setup etc',
#  'work with managed service providers to develop',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent experience in',
#  'and devops framework projects managed within the hr digital',
#  'pharmaceutical experience or a master degree in statistics biostatistics|experience or a master degree in statistics biostatistics and',
#  'biology is essential including bachelor s or graduate level',
#  'a minimum of a bachelor s degree and specialization|of a bachelor s degree and specialization in finance',
#  'sap certification on fi co and|s4 hana or related certifications is preferred',
#  'years relevant experience or master s in statistics or',
#  'a minimum of a bachelor s degree in computer|of a bachelor s degree in computer science or',
#  'an advanced degree',
#  'requires a bs ba degree 5 7 years of',
#  'or any combination of education and experienced which would',
#  'project management certification pmp preferred',
#  'beacon health options has changed the way people live',
#  'or any combination of education and experience which would',
#  'with datasets of varying degrees of size and complexity',
#  'bachelor s degree in statistics|bachelor s degree in statistics computer science',
#  'or any combination of education and experience which would',
#  'requires a ba bs degree',
#  'or any combination of education and experience which would',
#  'bachelor s degree in accounting|bachelor s degree in accounting finance it',
#  'bachelor s degree in related|bachelor s degree in related field or',
#  'degree in data science computer',
#  'test plan reviews bachelor s degree or higher|plan reviews bachelor s degree or higher in computer',
#  'degree in computer systems design',
#  'masters degree in computer systems|masters degree in computer systems design',
#  'risk factors and the degree to which they could',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'frm or cfa certification is a plus as',
#  'bachelor degree or equivalent|bachelor degree or equivalent',
#  'applicable security certifications desired',
#  'or csslp or advanced degree in infosec',
#  'aws architecture certification professional preferred',
#  'bachelor s degree in information|bachelor s degree in information technology computer',
#  'bachelor s degree in related|bachelor s degree in related discipline understanding',
#  'bachelor s degree from an|bachelor s degree from an accredited college',
#  'bachelor s degree or higher|bachelor s degree or higher in computer',
#  'master s or ph d',
#  'degree in computer science engineering',
#  'bachelors with 7 years of',
#  'bachelor s degree in business|bachelor s degree in business finance computer',
#  'lean six sigma certification',
#  'salesforce admin certification',
#  'bachelor s degree in hr|bachelor s degree in hr org development',
#  'education',
#  'bachelor s degree|bachelor s degree',
#  'bachelor s degree in a|bachelor s degree in a technical field|statistics or operations research master s or phd a',
#  'education',
#  'master s degree|master s degree',
#  'education',
#  'bachelor s degree|bachelor s degree',
#  'education',
#  'bachelor s degree|bachelor s degree',
#  'certifications',
#  'resources phr human resource certification institute human resource certification|certification institute human resource certification institute',
#  'education',
#  'bachelor s degree|bachelor s degree',
#  '7 10 years phr certification preferred responsible for partnering',
#  'degree or equivalent and typically',
#  'the degree should be in computer',
#  'education',
#  'masters 3yrs work experience or',
#  'education',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent experienc',
#  'education training',
#  '4 year degree in related field such',
#  'sphr or shrm scp certification is a plus',
#  'required education including major bachelor s|required education including major bachelor s degree in related|including major bachelor s degree in related field',
#  'for each year of degree level education|year of degree level education',
#  'bachelor s degree typically in|bachelor s degree typically in science technology|laws regulations or advanced degree in a related field',
#  'in absence of a degree 9 years of relevant',
#  'systems security professional cissp certification',
#  'communication and diplomatic skills',
#  'bachelor s degree in computer|bachelor s degree in computer science information|experience in lieu of degree',
#  'bachelor s degree and 2|bachelor s degree and 2 years of',
#  'in absence of a degree 6 years of relevant',
#  'bachelors degree in human resources|bachelors degree in human resources human',
#  'and programs that facilitate education awareness and positive employee',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent work experience',
#  'phr sphr or gphr certification preferred',
#  'bachelor s degree in computer|bachelor s degree in computer science software',
#  'bachelor s degree computer science|bachelor s degree computer science or related',
#  'master s degree|master s degree',
#  'project management professional pmp certification',
#  'certification in area of expertise',
#  'defined datacenter technologies hyper converged datacenter hardware solutions and',
#  'bachelor of science degree in|bachelor of science degree in human resources or',
#  'advanced degree mba or masters degree|advanced degree mba or masters degree in related hr|degree mba or masters degree in related hr field',
#  'are in place and managed effectively for all critical',
#  'bachelor s degree required advanced|bachelor s degree required advanced degree desired|s degree required advanced degree desired',
#  'bachelor s degree in business|bachelor s degree in business hr behavioral',
#  'in lieu of a degree',
#  'bachelor s degree|bachelor s degree',
#  'mba or master s degree with a|mba or master s degree with a concentration in',
#  'education experience typically acquired through|typically acquired through advanced education e g',
#  'bachelor and typically 6 or|an equivalent combination of education and experience e g',
#  'master 4 years related work',
#  'human resources certification',
#  'bachelor s degree|bachelor s degree',
#  'in lieu of a degree',
#  'graduated recently with a bachelors masters or mba degree|recently with a bachelors masters or mba degree and|bachelors masters or mba degree and have a major',
#  'education',
#  'bachelor s degree in hr|bachelor s degree in hr or related',
#  'advanced degree or certification in labor|advanced degree or certification in labor relations is',
#  'education',
#  'bachelor s degree in human|bachelor s degree in human resources business',
#  'years of management experience master s degree preferred|management experience master s degree preferred',
#  'certifications for human resource professionals',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent post secondary|or equivalent post secondary degree required in human resources',
#  'master s degree or mba|master s degree or mba in hrm',
#  'maintains documentation and certifications for providing child health',
#  'upon to perform patient education duties as well as',
#  'previous experience with managed care and medicaid wellness',
#  'providing evidence based patient education shared decision making and',
#  'providing evidence based patient education shared decision making and',
#  'master s degree phd is|master s degree phd is a plus',
#  'providing evidence based patient education shared decision making and',
#  'providing evidence backed patient education shared decision making and',
#  'providing evidence based patient education shared decision making and',
#  'phone triage and patient education',
#  'of vaccines and cpr certification required',
#  'initiates patient education as prescribed by physician',
#  'education and or experience minimum|minimum of associate s degree adn or equivalent from',
#  'acls certification',
#  'and as consistent with education experience presented on resume|on resume cv application certification and licensing',
#  'provide medical and wellness education',
#  'provide patient education health literacy identify patient',
#  'identify patient education desires',
#  'education',
# ...
#  'or any combination of education and experience which would',
#  'of america s largest managed healthcare organizations',
#  'provides psychiatric health services education counseling and emotional support',
#  'or any combination of education and experience which would',
#  'for this position board certification pmhnp bc highly preferred',
#  'valid bls certification preferred',
#  'of america s largest managed healthcare organizations',
#  'or any combination of education and experience which would',
#  'of america s largest managed healthcare organizations',
#  'a and network certifications preferred',
#  'bachelor s degree preferred|bachelor s degree preferred',
#  'service equivalent combination of education training and experience',
#  'and problem solving skills bachelor s degree preferred|solving skills bachelor s degree preferred',
#  'minimal supervision two year degree preferred',
#  'systems and have worked managed macos linux and windows',
#  'ultimately they ll be judged on the delivery and',
#  'or 5 with a master s degree|with a master s degree',
#  'you want to be judged by your outcomes',
#  'preference for a bachelor s or master s|a bachelor s or master s degree in software|s or master s degree in software engineering computer',
#  'bachelor s degree in a|bachelor s degree in a stem field',
#  'microsoft certifications a plu',
#  'master front s product capabilities',
#  'master data management business intelligence',
#  'bachelor s degree in management|bachelor s degree in management information systems',
#  'desk support analyst with managed services experience',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent experience',
#  'development activities including continuing education',
#  'spirit and contagious energy bachelor s degree in information|contagious energy bachelor s degree in information technology or|in information technology or degree in related field',
#  'hospitality primary and higher education justice and solar energy',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'degree in software development or',
#  'and or comptia network certifications',
#  'bachelor s degree or foreign|bachelor s degree or foreign equivalent in',
#  'college degree or equivalent work experience',
#  'some project work bachelor s degree or equivalent|project work bachelor s degree or equivalent experience',
#  'associates degree or equivalent experience basic',
#  'associate s degree or certificate in a',
#  'education high school diploma and|education high school diploma and 2 years of',
#  'license certifications a is preferred and',
#  'operating computer systems preferred certifications a network security',
#  'microsoft certifications are a plus',
#  'high school diploma or equivalent',
#  'bachelor s degree preferred|bachelor s degree preferred',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent',
#  'itil foundations certification preferred',
#  'security fundamentals technology applications managed services industry best practices',
#  'bachelor s degree in information|bachelor s degree in information technology or',
#  'a high degree of flexibility independence initiative',
#  'industry certification s strongly preferred a',
#  'bachelor s degree|bachelor s degree',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent experience in|marketing or another related degree',
#  'support skills preferred microsoft certification or associate s degree|certification or associate s degree',
#  'engineer has a high degree of ownership and potential',
#  'high school diploma or ged required|high school diploma or ged required',
#  'bachelor s degree in related|bachelor s degree in related it field|field or appropriate it certification highly desired',
#  'bs degree and three to five',
#  'or developer dev i certifications preferred the trade desk',
#  'bachelor s or master s|bachelor s or master s degree in computer|s or master s degree in computer science information',
#  'mastery in english and local',
#  'mastery in english and local',
#  'bachelor s or master s|bachelor s or master s degree in computer|s or master s degree in computer science engineering',
#  'minimum vocational diploma associate degree technical field|minimum vocational diploma associate degree technical field equivalent with|in related fields or degree holder with 1 2',
#  'bachelor s degree or foreign|bachelor s degree or foreign equivalent in',
#  'bachelor s degree in web|bachelor s degree in web development or',
#  'communications employing a high degree of customer service technical',
#  'associate s degree a',
#  'or equivalent combination of education and experience',
#  'bachelor s degree b a|bachelor s degree b a from four',
#  'it industry certifications mcsa a network etc',
#  'state that can be leveraged by software developers both',
#  'bachelor s degree required|bachelor s degree required',
#  'bachelor s degree required or|bachelor s degree required or 4 additional|in lieu of a degree',
#  'itil and or itam certifications',
#  'engaged in all phases of',
#  'writing programming publications pursuing educational opportunities establishing personal networks',
#  'bachelor s degree in related|bachelor s degree in related field of',
#  'bachelor s degree in computer|bachelor s degree in computer science engineering',
#  'bachelor s degree preferred|bachelor s degree preferred',
#  'experience in lieu of degree',
#  'bachelor s degree|bachelor s degree',
#  'needed to meet their educational goals',
#  'education associate s degree in|education associate s degree in information technology or',
#  'experience and applicable it certifications may be substituted for|may be substituted for education on a case by',
#  'and similar it industry certifications a plu',
#  'access to quality nursing education',
#  'best place for nursing education and the best place',
#  'promise of extraordinary nursing education matched only by a',
#  'multivariate and targeted experiences bachelor s degree|targeted experiences bachelor s degree',
#  'currently pursuing a degree in computer science software',
#  'hold a bachelor s degree prior to|hold a bachelor s degree prior to the intended',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'or any combination of education and experience which would',
#  'oracle required certifications preferred',
#  'information technology or equivalent education and experience',
#  'associate or bachelor s degree in information|associate or bachelor s degree in information science information',
#  'bachelor s degree in computer|bachelor s degree in computer science computer',
#  'master s degree or phd|master s degree or phd in computer',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'bachelor s degree or relevant|bachelor s degree or relevant experience',
#  'while displaying a high degree of flexibility and professionalism',
#  'the company and are encouraged at all levels of',
#  'bachelor s degree related to|bachelor s degree related to information systems',
#  'bs degree in computer science or',
#  'high school diploma ged or high school|high school diploma ged or high school equivalency',
#  'and display a high degree of initiative and drive',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'aws certification is a plus',
#  'high school diploma ged or high school|high school diploma ged or high school equivalency',
#  'bachelors and or master s|bachelors and or master s degree in computer|and or master s degree in computer science information',
#  'aws certifications will put you at',
#  'impromptu cognos or sql bachelor s degree in computer|or sql bachelor s degree in computer science information',
#  'team and processes undergraduate degree or equivalent work experience',
#  'a given business problem bachelor s degree|business problem bachelor s degree',
#  'maintenance employees high school diploma ged or higher|employees high school diploma ged or higher',
#  'environment where success was gauged by balancing first call',
#  'environment where success was gauged by balancing first call',
#  'bachelor s degree and less|bachelor s degree and less than 2',
#  'bachelor s degree in computer|bachelor s degree in computer science information',
#  'bachelor s degree and at|bachelor s degree and at least 2|or a high school diploma ged and at least|a high school diploma ged and at least 5',
#  'associate s degree or higher and at|or a high school diploma ged and at least|a high school diploma ged and at least 4',
#  'bachelor s degree|bachelor s degree',
#  'associate degree or bachelor s degree|associate degree or bachelor s degree in information|degree or bachelor s degree in information security information',
#  'sans related certifications gsec gcia gced gcih',
#  'other field appropriate certifications may be considered',
#  'bs degree in computer science or',
#  'maintains a high degree of professionalism in actions',
#  'educated to a level degree standard',
#  'specific certifications i e a network',
#  'member on a highly engaged and very proficient team',
#  'and or supporting existing packaged or custom built applications',
#  'education undergraduate studies in computer|systems or other related degree',
#  'substituted for an undergraduate degree',
#  'solutions have a high degree of reliability availability serviceability',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'of program managers scrum masters engineers design product owners',
#  'with a combination of education and technical experience that',
#  'undergraduate degree in computer science engineering',
#  'shared services team is charged with driving continuous alignment',
#  'more relevant experience and masters degree in a technical|relevant experience and masters degree in a technical it|additional relevant experience plus bachelors degree|relevant experience plus bachelors degree',
#  'of experience and a bachelor s degree in a|and a bachelor s degree in a technical it',
#  'bachelor s degree in software|bachelor s degree in software engineering or',
#  'or master s degree|or master s degree',
#  'industry certifications agile experience preferred',
#  'high school diploma ged with 10 years|high school diploma ged with 10 years of|experience or associate s degree with 8 years of|8 years of experience bachelor s degree with 6|of experience bachelor s degree with 6 years of|years of experience or master s degree with 4|experience or master s degree with 4 years experience',
#  'ii computing environment ce certification as determined by the',
#  'required baseline security environment certification comptia security ce or',
#  'required desired computing environment certification ciw web developer javascript',
#  'master s degree and 8|master s degree and 8 years of|or equivalent combination of education and experience',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent practical experience',
#  'master s degree or phd|master s degree or phd in engineering',
#  'are a small team charged with the continued support',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent practical experience',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'of work history and education',
#  'years of experience or masters and 10 years bachelors|masters and 10 years bachelors and 12 years associates',
#  'the degree must be in computer',
#  'required qualifications minimum education and experience level high|experience level high school ged and four 4 years|of experience and 8570 certification',
#  'this position requires a bachelor s degree or equivalent|requires a bachelor s degree or equivalent in electrical',
#  '4 year degree or equivalent experience',
#  'training and self directed education experience with node js',
#  'bachelor of science in computer',
#  'interact with third party managed security service providers as',
#  'professional it security certifications such as cissp cism',
#  'bachelor s degree required|bachelor s degree required',
#  'bachelor s degree in business|bachelor s degree in business administration or|or equivalent work or education related experience certified information',
#  'security certifications',
#  'bs or ms degree in computer science computer',
#  'bachelor s degree in marketing|bachelor s degree in marketing communications business',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent work experience',
#  'bachelor s degree with 1|bachelor s degree with 1 year experience|experience or high school diploma equivalent with 5 yrs',
#  'substituted in lieu of degree',
#  'security certification',
#  'operations or other cisco certifications',
#  '2 0 or higher certification',
#  'bachelors degree in a science|bachelors degree in a science technology',
#  'masters with 3 years',
#  'current comptia security certification or equivalent',
#  'high school diploma or equivalent',
#  'current comptia security ce certification or ability to obtain|of hire aa or bachelor s degree|aa or bachelor s degree',
#  'bachelor s degree in a|bachelor s degree in a related field',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'high school diploma ge',
#  'bachelor s in computer science',
#  'or a master s degree with 2|or a master s degree with 2 years of',
#  'to problems utilizing formal education and judgment',
#  'bachelors or masters degree in|bachelors or masters degree in computer science|bachelors or masters degree in computer science information',
#  'must have the required degree or expect the required|or expect the required degree by september 2021',
#  'ba bs degree in computer science or',
#  'billing and ar perspective bachelor s degree or four|ar perspective bachelor s degree or four or more',
#  'ba bs degree with concentration in accounting',
#  'improving consumer experiences associates degree',
#  'product owner and scrum master',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'advanced degree eg',
#  'bachelor master etc preferred but|bachelor master etc preferred but not',
#  'web development or a bachelor s degree in information|or a bachelor s degree in information systems computer',
#  'experience using managed attribution systems',
#  'bachelor s degree or higher|bachelor s degree or higher',
#  'comptia security certification preferred',
#  'to obtain comptia security certification post start',
#  'advanced degree e g',
#  'bachelor master phd etc preferred|bachelor master phd etc preferred but',
#  'capital markets experience a masters degree or higher in|markets experience a masters degree or higher in computer',
#  'a professional certification in technology',
#  'a minimum of a bachelor s degree or relevant|of a bachelor s degree or relevant military experience',
#  'a degree discipline in computer science',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'associates degree in computer science or',
#  'publix and our mission certifications in the field of|science such as cisco certification a certification microsoft certified|as cisco certification a certification microsoft certified systems engineer|certified systems engineer hp certification or lexmark certification|hp certification or lexmark certification',
#  'bachelor s degree or equivalent|bachelor s degree or equivalent combination of|or equivalent combination of education and years of experience',
#  'high school diploma or ged 2 years|high school diploma or ged 2 years support experience',
#  'bachelor s degree in computer|bachelor s degree in computer science or',
#  'low latency switch fabric managed and controlled via grid|controlled via grid engine master scheduler',
#  'bachelor s degree bs ba|bachelor s degree bs ba in computer',
#  'master s degree ms ma|master s degree ms ma in computer',
#  'applicable industry certifications such as security certified',
#  'your skills training and education',
#  'bachelor s degree from an|bachelor s degree from an accredited college|or equivalent experience combined education with 3 years of',
#  ...]

# %%
## helper function to run CREAM on all data points
def __helper__(row):
    global keywords
    global model
    global rule_map
    global encoded_rules
    
    THRESHOLD = 0.9
    
    text = row["Job Description"]
    context = get_context(text, keywords).split('|')
    
    if len(context) > 0 and context[0] != "":
        all_scores = []
        for c in context:
            scores = get_sim(model, rule_map, encoded_rules, c)
            all_scores.append(label_from_max(scores, rule_map))
        max_score = max(all_scores, key=itemgetter(2))
        if max_score[2] >= THRESHOLD:
            return max_score[0], max_score[1], max_score[2]
        else:
            return None, 0, None
    else:
        return None, None, None

# %%
data[['inferred_rule', 'inferred_label', 'inferred_confidence']] = data.apply(__helper__, axis=1, result_type="expand")

# %%
# all matches exceeding our set threshold
data[data['inferred_rule'].isna() == False]
# Out:
#                                          Job Description  \
# 69     Bachelor’s degree preferred, or equivalent com...
# 163    Own a basic set of hand tools High school dipl...
# 303    Bachelor's degree in construction management, ...
# 328    You’ll be a great fit if in addition to the co...
# 329    Bachelor’s degree, preferred in Business, Fina...
# ...                                                  ...
# 27571  Must have a high school diploma or GED and be ...
# 27607  Education and Experience: Completion of a home...
# 27624  Licensure, certification, and/or registration:...
# 27660                             License/Certifications
# 27689  Education: High School graduate or GED or equi...
#
#                        inferred_rule  inferred_label  inferred_confidence
# 69                    nursing degree             1.0             0.922145
# 163      degree required high school             1.0             0.969878
# 303    bachelor degree or equivalent             1.0             0.907762
# 328     general education degree ged             1.0             0.966497
# 329                   nursing degree             1.0             0.927838
# ...                              ...             ...                  ...
# 27571    degree required high school             1.0             0.938976
# 27607      education bachelor degree             1.0             0.926923
# 27624       experience or a bachelor             1.0             0.906362
# 27660                  certification             0.0             0.921547
# 27689                 ged equivalent             1.0             0.927827
#
# [691 rows x 4 columns]

# %%
# all matches exceeding threshold and receiving a label of 1 (true)
data[data['inferred_label'] == 1]
# Out:
#                                          Job Description  \
# 69     Bachelor’s degree preferred, or equivalent com...
# 163    Own a basic set of hand tools High school dipl...
# 303    Bachelor's degree in construction management, ...
# 328    You’ll be a great fit if in addition to the co...
# 329    Bachelor’s degree, preferred in Business, Fina...
# ...                                                  ...
# 27533        High School Diploma or equivalent required.
# 27571  Must have a high school diploma or GED and be ...
# 27607  Education and Experience: Completion of a home...
# 27624  Licensure, certification, and/or registration:...
# 27689  Education: High School graduate or GED or equi...
#
#                        inferred_rule  inferred_label  inferred_confidence
# 69                    nursing degree             1.0             0.922145
# 163      degree required high school             1.0             0.969878
# 303    bachelor degree or equivalent             1.0             0.907762
# 328     general education degree ged             1.0             0.966497
# 329                   nursing degree             1.0             0.927838
# ...                              ...             ...                  ...
# 27533           a high school degree             1.0             0.923840
# 27571    degree required high school             1.0             0.938976
# 27607      education bachelor degree             1.0             0.926923
# 27624       experience or a bachelor             1.0             0.906362
# 27689                 ged equivalent             1.0             0.927827
#
# [636 rows x 4 columns]
